# %%
from PIL import Image

# %%
from PIL import Image
foo = Image.open('test_red.jpg')  # My image is a 200x374 jpeg that is 102kb large
foo.size  # (200, 374)

 # downsize the image with an ANTIALIAS filter (gives the highest quality)
foo = foo.resize((160,300),Image.contain())

foo.save('image_scaled.jpg', quality=95)  # The saved downsized image size is 24.8kb

foo.save('image_scaled_opt.jpg', optimize=True, quality=95)  # The saved downsized image size is 22.9kb
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 5
#       2 foo.size  # (200, 374)
#       4  # downsize the image with an ANTIALIAS filter (gives the highest quality)
# ----> 5 foo = foo.resize((160,300),Image.ANTIALIAS)
#       7 foo.save('image_scaled.jpg', quality=95)  # The saved downsized image size is 24.8kb
#       9 foo.save('image_scaled_opt.jpg', optimize=True, quality=95)
#
# AttributeError: module 'PIL.Image' has no attribute 'ANTIALIAS'

# %%
from PIL import Image

foo = Image.open('test_red.jpg')  # Open the image
print(foo.size)  # Check the original size (200, 374)


foo.save('image_scaled_opt.jpg', optimize=True, quality=70)  # Optimized version
# Out:
# (790, 1053)

# %%
red = Image.open("test_red.jpg")

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=790x1053>

# %%
print(red.format, red.size, red.mode)
# Out:
# JPEG (790, 1053) RGB

# %%
red_compressed = Image.open('image_scaled_opt.jpg')
red_compressed
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=790x1053>

# %%
import os
from PIL import Image

# Open the image
Image.open(red_compressed)

# Get and print physical file size
file_path = 'image_scaled_opt.jpg'
file_size = os.path.getsize(file_path)  # Size in bytes

# Convert to KB or MB
file_size_kb = file_size / 1024  # Size in KB
file_size_mb = file_size_kb / 1024  # Size in MB

print(f"Format: {red.format}")
print(f"Size: {red.size}")
print(f"Mode: {red.mode}")
print(f"File Size: {file_size} bytes ({file_size_kb:.2f} KB or {file_size_mb:.2f} MB)")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 5
#       2 from PIL import Image
#       4 # Open the image
# ----> 5 Image.open(red_compressed)
#       7 # Get and print physical file size
#       8 file_path = 'image_scaled_opt.jpg'
#
# File ~/miniconda3/lib/python3.12/site-packages/PIL/Image.py:3442, in open(fp, mode, formats)
#    3439     fp = io.BytesIO(fp.read())
#    3440     exclusive_fp = True
# -> 3442 prefix = fp.read(16)
#    3444 preinit()
#    3446 warning_messages: list[str] = []
#
# AttributeError: 'JpegImageFile' object has no attribute 'read'

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=790x1053>
